# %%
pip install -q recommenders faiss-gpu
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
import numpy as np


def apk(actual, predicted, k=12):
    """
    Computes the average precision at k.

    This function computes the average prescision at k between two lists of
    items.

    Parameters
    ----------
    actual : list
             A list of elements that are to be predicted (order doesn't matter)
    predicted : list
                A list of predicted elements (order does matter)
    k : int, optional
        The maximum number of predicted elements

    Returns
    -------
    score : double
            The average precision at k over the input lists

    """
    if len(predicted) > k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i, p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i + 1.0)

    if not actual:
        return 0.0

    return score / min(len(actual), k)


def mapk(actual, predicted, k=12):
    """
    Computes the mean average precision at k.

    This function computes the mean average prescision at k between two lists
    of lists of items.

    Parameters
    ----------
    actual : list
             A list of lists of elements that are to be predicted
             (order doesn't matter in the lists)
    predicted : list
                A list of lists of predicted elements
                (order matters in the lists)
    k : int, optional
        The maximum number of predicted elements

    Returns
    -------
    score : double
            The mean average precision at k over the input lists

    """
    return np.mean([apk(a, p, k) for a, p in zip(actual, predicted)])

# %%
import gc
import sys
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import faiss
tf.get_logger().setLevel('ERROR') # only show error messages

from recommenders.utils.timer import Timer
from recommenders.models.deeprec.models.graphrec.lightgcn import LightGCN
from recommenders.models.deeprec.DataModel.ImplicitCF import ImplicitCF
from recommenders.models.deeprec.deeprec_utils import prepare_hparams
import datetime
from pathlib import Path

print("System version: {}".format(sys.version))
print("Pandas version: {}".format(pd.__version__))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:21)
# [GCC 9.4.0]
# Pandas version: 1.3.5
# Tensorflow version: 2.8.0

# %%
if os.getenv('LOCAL'):
    print('local')
    INPUT_DIR = Path('./input/transformed')
    OUTPUT_DIR = Path('./output')
else:
    print('kaggle')
    INPUT_DIR = Path('../input/transformed')
    OUTPUT_DIR = Path('/kaggle/working')
# Out:
# local

# %%
transactions = pd.read_pickle(INPUT_DIR / 'transactions_train.pkl')[['user', 'item', 't_dat']]
valid_start_date = datetime.date(2020, 9, 16)

# %%
def train_valid_stats(train, valid):
    train_users = set(train.user)
    train_items = set(train.item)
    valid_users = set(valid.user)
    valid_items = set(valid.item)
    print(f"train transaction: {len(train)}, train user: {len(train_users)}, train item: {len(train_items)}")
    print(f"valid transaction: {len(valid)}, valid user: {len(valid_users)}, valid item: {len(valid_items)}")
    print(f"valid user coverage: {len(train_users & valid_users) / len(valid_users)}")
    print(f"valid item coverage: {len(train_items & valid_items) / len(valid_items)}")

# %%
train_days = 60
recent_item_days = 7
recent_user_days = 21

# %%
print("train vaild split")
train_start_date = valid_start_date - datetime.timedelta(days=train_days)
train = transactions.query("@train_start_date <= t_dat < @valid_start_date").reset_index(drop=True)
valid = transactions.query("@valid_start_date <= t_dat").reset_index(drop=True)
del transactions
train_valid_stats(train, valid)
# Out:
# train vaild split
# train transaction: 2383043, train user: 398740, train item: 36700
# valid transaction: 240311, valid user: 68984, valid item: 17986
# valid user coverage: 0.6308999188217558
# valid item coverage: 0.9427888357611476

# %%
print("filter recent items")
train_item_start_date = valid_start_date - datetime.timedelta(days=recent_item_days)
recent_items = set(train.query("@train_item_start_date <= t_dat < @valid_start_date")['item'])
train = train.query("item in @recent_items").reset_index(drop=True)
train_valid_stats(train, valid)
# Out:
# filter recent items
# train transaction: 2222314, train user: 393030, train item: 18611
# valid transaction: 240311, valid user: 68984, valid item: 17986
# valid user coverage: 0.6251449611504117
# valid item coverage: 0.775992438563327

# %%
print("filter each user recent transactions (train)")
train['last_t_dat'] = train.groupby('user').t_dat.transform(max)
train['diff_t_dat'] = (train.last_t_dat - train.t_dat).dt.days
train = train.query("diff_t_dat < @recent_user_days").reset_index(drop=True)
train_valid_stats(train, valid)
# Out:
# filter each user recent transactions (train)
# train transaction: 1742914, train user: 393030, train item: 18611
# valid transaction: 240311, valid user: 68984, valid item: 17986
# valid user coverage: 0.6251449611504117
# valid item coverage: 0.775992438563327

# %%
print("drop duplicates (train)")
train = train[['user', 'item']]
valid = valid[['user', 'item']]
train = train.drop_duplicates(ignore_index=True)
train_valid_stats(train, valid)
# Out:
# drop duplicates (train)
# train transaction: 1543484, train user: 393030, train item: 18611
# valid transaction: 240311, valid user: 68984, valid item: 17986
# valid user coverage: 0.6251449611504117
# valid item coverage: 0.775992438563327

# %%
print("drop users and items which apper only once (train)")
for _ in range(3):
    users = train.groupby('user').size().reset_index(name='sz').query("sz > 1").user
    train = train.query("user in @users")
    print(train.shape, len(train.user.unique()), len(train.item.unique()))

    items = train.groupby('item').size().reset_index(name='sz').query("sz > 1").item
    train = train.query("item in @items")
    print(train.shape, len(train.user.unique()), len(train.item.unique()))

train_valid_stats(train, valid)
# Out:
# drop users and items which apper only once (train)
# (1449505, 2) 299051 18561
# (1448666, 2) 299049 17722
# (1448569, 2) 298952 17722
# (1448564, 2) 298952 17717
# (1448564, 2) 298952 17717
# (1448564, 2) 298952 17717
# train transaction: 1448564, train user: 298952, train item: 17717
# valid transaction: 240311, valid user: 68984, valid item: 17986
# valid user coverage: 0.5110460396613707
# valid item coverage: 0.7604803736239297

# %%
# LightGCNが学習できるような形式にする
# - testのみに含まれるユーザーがあってはいけない
# - カラム名をあわせる
# - ratingカラムを追加
users = sorted(set(train.user))
valid = valid.query("user in @users")

train = train.rename(columns={'user': 'userID', 'item': 'itemID'})
valid = valid.rename(columns={'user': 'userID', 'item': 'itemID'})
train['rating'] = 1
valid['rating'] = 1

train.head()
# Out:
#    userID  itemID  rating
# 0     901   58299       1
# 1     901   58296       1
# 2     901   63118       1
# 3     901   21236       1
# 4     901   57464       1

# %%
data = ImplicitCF(train=train, test=valid, seed=42)

# %%
hparams = prepare_hparams(
    model_type='lightgcn',
    embed_size=128,
    n_layers=3,
    batch_size=8192,
    decay=0.0001,
    epochs=1000,
    learning_rate=0.001,
    eval_epoch=10,
    top_k=12,
    save_model=True,
    save_epoch=100,
    metrics=['recall', 'ndcg', 'precision', 'map'],
    MODEL_DIR=str(OUTPUT_DIR),
)
with Timer() as prepare_time:
    model = LightGCN(hparams, data, seed=42)
del data
print(f"{prepare_time.interval} sec")
# Out:
# Already create adjacency matrix.
# Already normalize adjacency matrix.
# Using xavier initialization.
# 2022-03-15 11:38:59.771326: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-15 11:38:59.806102: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-15 11:38:59.810785: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-15 11:38:59.810998: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-15 11:39:00.154652: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-15 11:39:00.154869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-15 11:39:00.155043: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-15 11:39:00.155199: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9004 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# 193.96733661399958 sec

# %%
gc.collect()
with Timer() as train_time:
    model.fit()
print(f"{train_time.interval} sec")
# Out:
# Epoch 1 (train)28.0s: train loss = 0.62637 = (mf)0.62633 + (embed)0.00004
# Epoch 2 (train)27.3s: train loss = 0.31989 = (mf)0.31952 + (embed)0.00038
# Epoch 3 (train)27.2s: train loss = 0.25804 = (mf)0.25748 + (embed)0.00056
# Epoch 4 (train)27.4s: train loss = 0.21830 = (mf)0.21760 + (embed)0.00069
# Epoch 5 (train)27.5s: train loss = 0.18945 = (mf)0.18862 + (embed)0.00082
# Epoch 6 (train)27.6s: train loss = 0.16695 = (mf)0.16600 + (embed)0.00095
# Epoch 7 (train)27.4s: train loss = 0.15032 = (mf)0.14926 + (embed)0.00107
# Epoch 8 (train)27.4s: train loss = 0.13645 = (mf)0.13526 + (embed)0.00118
# Epoch 9 (train)27.7s: train loss = 0.12543 = (mf)0.12414 + (embed)0.00129
# Epoch 10 (train)27.6s + (eval)10.7s: train loss = 0.11588 = (mf)0.11448 + (embed)0.00139, recall = 0.01811, ndcg = 0.01183, precision = 0.00498, map = 0.00624
# Epoch 11 (train)27.6s: train loss = 0.10805 = (mf)0.10656 + (embed)0.00149
# Epoch 12 (train)27.8s: train loss = 0.10088 = (mf)0.09930 + (embed)0.00158
# Epoch 13 (train)27.9s: train loss = 0.09492 = (mf)0.09325 + (embed)0.00167
# Epoch 14 (train)27.7s: train loss = 0.08922 = (mf)0.08746 + (embed)0.00176
# Epoch 15 (train)27.4s: train loss = 0.08445 = (mf)0.08261 + (embed)0.00184
# Epoch 16 (train)27.8s: train loss = 0.07993 = (mf)0.07801 + (embed)0.00192
# Epoch 17 (train)27.5s: train loss = 0.07603 = (mf)0.07402 + (embed)0.00200
# Epoch 18 (train)27.6s: train loss = 0.07227 = (mf)0.07019 + (embed)0.00208
# Epoch 19 (train)27.6s: train loss = 0.06829 = (mf)0.06614 + (embed)0.00215
# Epoch 20 (train)27.8s + (eval)9.8s: train loss = 0.06546 = (mf)0.06324 + (embed)0.00222, recall = 0.02156, ndcg = 0.01375, precision = 0.00575, map = 0.00739
# Epoch 21 (train)27.5s: train loss = 0.06292 = (mf)0.06063 + (embed)0.00229
# Epoch 22 (train)27.5s: train loss = 0.05950 = (mf)0.05714 + (embed)0.00236
# Epoch 23 (train)27.4s: train loss = 0.05712 = (mf)0.05469 + (embed)0.00243
# Epoch 24 (train)27.7s: train loss = 0.05464 = (mf)0.05215 + (embed)0.00249
# Epoch 25 (train)27.6s: train loss = 0.05237 = (mf)0.04982 + (embed)0.00256
# Epoch 26 (train)27.6s: train loss = 0.05030 = (mf)0.04768 + (embed)0.00262
# Epoch 27 (train)27.4s: train loss = 0.04828 = (mf)0.04560 + (embed)0.00268
# Epoch 28 (train)27.7s: train loss = 0.04650 = (mf)0.04376 + (embed)0.00274
# Epoch 29 (train)27.7s: train loss = 0.04470 = (mf)0.04190 + (embed)0.00279
# Epoch 30 (train)27.7s + (eval)10.1s: train loss = 0.04304 = (mf)0.04019 + (embed)0.00285, recall = 0.02270, ndcg = 0.01499, precision = 0.00603, map = 0.00838
# Epoch 31 (train)27.7s: train loss = 0.04206 = (mf)0.03916 + (embed)0.00290
# Epoch 32 (train)27.6s: train loss = 0.04056 = (mf)0.03760 + (embed)0.00295
# Epoch 33 (train)27.5s: train loss = 0.03880 = (mf)0.03580 + (embed)0.00300
# Epoch 34 (train)27.3s: train loss = 0.03751 = (mf)0.03446 + (embed)0.00305
# Epoch 35 (train)27.5s: train loss = 0.03638 = (mf)0.03328 + (embed)0.00310
# Epoch 36 (train)27.7s: train loss = 0.03513 = (mf)0.03199 + (embed)0.00315
# Epoch 37 (train)27.7s: train loss = 0.03399 = (mf)0.03080 + (embed)0.00319
# Epoch 38 (train)27.6s: train loss = 0.03340 = (mf)0.03017 + (embed)0.00323
# Epoch 39 (train)27.6s: train loss = 0.03211 = (mf)0.02883 + (embed)0.00327
# Epoch 40 (train)27.7s + (eval)9.8s: train loss = 0.03105 = (mf)0.02773 + (embed)0.00332, recall = 0.02346, ndcg = 0.01609, precision = 0.00620, map = 0.00941
# Epoch 41 (train)27.4s: train loss = 0.03031 = (mf)0.02696 + (embed)0.00336
# Epoch 42 (train)27.4s: train loss = 0.02956 = (mf)0.02617 + (embed)0.00340
# Epoch 43 (train)27.6s: train loss = 0.02850 = (mf)0.02507 + (embed)0.00343
# Epoch 44 (train)27.3s: train loss = 0.02781 = (mf)0.02434 + (embed)0.00347
# Epoch 45 (train)27.6s: train loss = 0.02727 = (mf)0.02376 + (embed)0.00350
# Epoch 46 (train)27.9s: train loss = 0.02625 = (mf)0.02271 + (embed)0.00354
# Epoch 47 (train)27.8s: train loss = 0.02587 = (mf)0.02230 + (embed)0.00357
# Epoch 48 (train)27.6s: train loss = 0.02522 = (mf)0.02161 + (embed)0.00360
# Epoch 49 (train)27.7s: train loss = 0.02443 = (mf)0.02080 + (embed)0.00363
# Epoch 50 (train)27.6s + (eval)9.8s: train loss = 0.02381 = (mf)0.02014 + (embed)0.00366, recall = 0.02429, ndcg = 0.01680, precision = 0.00641, map = 0.00993
# Epoch 51 (train)27.5s: train loss = 0.02323 = (mf)0.01954 + (embed)0.00369
# Epoch 52 (train)27.5s: train loss = 0.02283 = (mf)0.01911 + (embed)0.00372
# Epoch 53 (train)27.6s: train loss = 0.02182 = (mf)0.01807 + (embed)0.00375
# Epoch 54 (train)27.8s: train loss = 0.02156 = (mf)0.01779 + (embed)0.00377
# Epoch 55 (train)27.6s: train loss = 0.02103 = (mf)0.01723 + (embed)0.00380
# Epoch 56 (train)27.4s: train loss = 0.02093 = (mf)0.01711 + (embed)0.00382
# Epoch 57 (train)27.5s: train loss = 0.02044 = (mf)0.01660 + (embed)0.00384
# Epoch 58 (train)27.6s: train loss = 0.01984 = (mf)0.01597 + (embed)0.00386
# Epoch 59 (train)27.3s: train loss = 0.01949 = (mf)0.01561 + (embed)0.00388
# Epoch 60 (train)27.5s + (eval)9.9s: train loss = 0.01905 = (mf)0.01515 + (embed)0.00390, recall = 0.02506, ndcg = 0.01732, precision = 0.00656, map = 0.01031
# Epoch 61 (train)27.3s: train loss = 0.01841 = (mf)0.01449 + (embed)0.00392
# Epoch 62 (train)27.1s: train loss = 0.01815 = (mf)0.01421 + (embed)0.00394
# Epoch 63 (train)27.2s: train loss = 0.01780 = (mf)0.01384 + (embed)0.00396
# Epoch 64 (train)27.4s: train loss = 0.01749 = (mf)0.01352 + (embed)0.00397
# Epoch 65 (train)27.5s: train loss = 0.01710 = (mf)0.01311 + (embed)0.00399
# Epoch 66 (train)27.5s: train loss = 0.01704 = (mf)0.01303 + (embed)0.00400
# Epoch 67 (train)27.5s: train loss = 0.01629 = (mf)0.01227 + (embed)0.00402
# Epoch 68 (train)27.4s: train loss = 0.01618 = (mf)0.01216 + (embed)0.00403
# Epoch 69 (train)27.6s: train loss = 0.01597 = (mf)0.01193 + (embed)0.00404
# Epoch 70 (train)27.4s + (eval)9.9s: train loss = 0.01569 = (mf)0.01164 + (embed)0.00405, recall = 0.02577, ndcg = 0.01785, precision = 0.00673, map = 0.01066
# Epoch 71 (train)27.1s: train loss = 0.01527 = (mf)0.01120 + (embed)0.00406
# Epoch 72 (train)27.3s: train loss = 0.01510 = (mf)0.01103 + (embed)0.00407
# Epoch 73 (train)27.4s: train loss = 0.01483 = (mf)0.01075 + (embed)0.00408
# Epoch 74 (train)27.6s: train loss = 0.01464 = (mf)0.01055 + (embed)0.00409
# Epoch 75 (train)27.7s: train loss = 0.01441 = (mf)0.01031 + (embed)0.00410
# Epoch 76 (train)27.6s: train loss = 0.01408 = (mf)0.00998 + (embed)0.00410
# Epoch 77 (train)27.7s: train loss = 0.01411 = (mf)0.00999 + (embed)0.00411
# Epoch 78 (train)27.6s: train loss = 0.01357 = (mf)0.00945 + (embed)0.00412
# Epoch 79 (train)27.6s: train loss = 0.01345 = (mf)0.00933 + (embed)0.00412
# Epoch 80 (train)27.6s + (eval)10.1s: train loss = 0.01334 = (mf)0.00922 + (embed)0.00412, recall = 0.02588, ndcg = 0.01807, precision = 0.00673, map = 0.01093
# Epoch 81 (train)27.6s: train loss = 0.01315 = (mf)0.00903 + (embed)0.00412
# Epoch 82 (train)27.6s: train loss = 0.01301 = (mf)0.00888 + (embed)0.00413
# Epoch 83 (train)27.8s: train loss = 0.01271 = (mf)0.00858 + (embed)0.00413
# Epoch 84 (train)27.7s: train loss = 0.01256 = (mf)0.00843 + (embed)0.00413
# Epoch 85 (train)27.6s: train loss = 0.01228 = (mf)0.00815 + (embed)0.00413
# Epoch 86 (train)27.5s: train loss = 0.01219 = (mf)0.00806 + (embed)0.00413
# Epoch 87 (train)27.4s: train loss = 0.01209 = (mf)0.00796 + (embed)0.00413
# Epoch 88 (train)27.5s: train loss = 0.01194 = (mf)0.00781 + (embed)0.00413
# Epoch 89 (train)27.5s: train loss = 0.01175 = (mf)0.00762 + (embed)0.00413
# Epoch 90 (train)27.5s + (eval)9.8s: train loss = 0.01158 = (mf)0.00745 + (embed)0.00413, recall = 0.02616, ndcg = 0.01827, precision = 0.00687, map = 0.01103
# Epoch 91 (train)27.4s: train loss = 0.01142 = (mf)0.00730 + (embed)0.00412
# Epoch 92 (train)27.5s: train loss = 0.01125 = (mf)0.00713 + (embed)0.00412
# Epoch 93 (train)27.5s: train loss = 0.01118 = (mf)0.00707 + (embed)0.00412
# Epoch 94 (train)27.7s: train loss = 0.01098 = (mf)0.00687 + (embed)0.00411
# Epoch 95 (train)27.6s: train loss = 0.01073 = (mf)0.00662 + (embed)0.00411
# Epoch 96 (train)27.5s: train loss = 0.01071 = (mf)0.00661 + (embed)0.00410
# Epoch 97 (train)27.7s: train loss = 0.01055 = (mf)0.00646 + (embed)0.00409
# Epoch 98 (train)27.8s: train loss = 0.01050 = (mf)0.00642 + (embed)0.00408
# Epoch 99 (train)27.5s: train loss = 0.01031 = (mf)0.00623 + (embed)0.00408
# Save model to path /home/wakatsuki/kaggle/h-and-m-personalized-fashion-recommendations/output/epoch_100
# Epoch 100 (train)27.6s + (eval)10.1s: train loss = 0.01024 = (mf)0.00617 + (embed)0.00407, recall = 0.02661, ndcg = 0.01853, precision = 0.00701, map = 0.01116
# Epoch 101 (train)27.8s: train loss = 0.01007 = (mf)0.00600 + (embed)0.00406
# Epoch 102 (train)27.6s: train loss = 0.01002 = (mf)0.00597 + (embed)0.00406
# Epoch 103 (train)27.4s: train loss = 0.00978 = (mf)0.00573 + (embed)0.00405
# Epoch 104 (train)27.6s: train loss = 0.00987 = (mf)0.00583 + (embed)0.00404
# Epoch 105 (train)27.5s: train loss = 0.00985 = (mf)0.00582 + (embed)0.00403
# Epoch 106 (train)27.5s: train loss = 0.00957 = (mf)0.00555 + (embed)0.00402
# Epoch 107 (train)27.5s: train loss = 0.00950 = (mf)0.00549 + (embed)0.00401
# Epoch 108 (train)27.5s: train loss = 0.00946 = (mf)0.00546 + (embed)0.00400
# Epoch 109 (train)27.5s: train loss = 0.00930 = (mf)0.00531 + (embed)0.00399
# Epoch 110 (train)27.5s + (eval)9.9s: train loss = 0.00914 = (mf)0.00516 + (embed)0.00398, recall = 0.02735, ndcg = 0.01905, precision = 0.00720, map = 0.01152
# Epoch 111 (train)27.5s: train loss = 0.00912 = (mf)0.00515 + (embed)0.00397
# Epoch 112 (train)27.6s: train loss = 0.00914 = (mf)0.00518 + (embed)0.00396
# Epoch 113 (train)27.5s: train loss = 0.00892 = (mf)0.00497 + (embed)0.00395
# Epoch 114 (train)27.2s: train loss = 0.00872 = (mf)0.00479 + (embed)0.00394
# Epoch 115 (train)27.1s: train loss = 0.00871 = (mf)0.00479 + (embed)0.00392
# Epoch 116 (train)27.7s: train loss = 0.00874 = (mf)0.00483 + (embed)0.00391
# Epoch 117 (train)27.3s: train loss = 0.00855 = (mf)0.00465 + (embed)0.00390
# Epoch 118 (train)27.1s: train loss = 0.00856 = (mf)0.00467 + (embed)0.00388
# Epoch 119 (train)27.5s: train loss = 0.00840 = (mf)0.00453 + (embed)0.00387
# Epoch 120 (train)27.4s + (eval)10.0s: train loss = 0.00826 = (mf)0.00440 + (embed)0.00386, recall = 0.02738, ndcg = 0.01908, precision = 0.00726, map = 0.01152
# Epoch 121 (train)27.5s: train loss = 0.00831 = (mf)0.00447 + (embed)0.00384
# Epoch 122 (train)27.4s: train loss = 0.00824 = (mf)0.00441 + (embed)0.00383
# Epoch 123 (train)27.4s: train loss = 0.00821 = (mf)0.00439 + (embed)0.00382
# Epoch 124 (train)27.4s: train loss = 0.00818 = (mf)0.00438 + (embed)0.00380
# Epoch 125 (train)27.3s: train loss = 0.00796 = (mf)0.00417 + (embed)0.00379
# Epoch 126 (train)27.5s: train loss = 0.00789 = (mf)0.00412 + (embed)0.00377
# Epoch 127 (train)27.5s: train loss = 0.00792 = (mf)0.00416 + (embed)0.00376
# Epoch 128 (train)27.8s: train loss = 0.00776 = (mf)0.00402 + (embed)0.00375
# Epoch 129 (train)27.5s: train loss = 0.00771 = (mf)0.00398 + (embed)0.00373
# Epoch 130 (train)27.5s + (eval)10.0s: train loss = 0.00761 = (mf)0.00389 + (embed)0.00372, recall = 0.02798, ndcg = 0.01957, precision = 0.00733, map = 0.01186
# Epoch 131 (train)27.6s: train loss = 0.00762 = (mf)0.00391 + (embed)0.00370
# Epoch 132 (train)27.2s: train loss = 0.00758 = (mf)0.00389 + (embed)0.00369
# Epoch 133 (train)27.4s: train loss = 0.00748 = (mf)0.00381 + (embed)0.00367
# Epoch 134 (train)27.5s: train loss = 0.00740 = (mf)0.00375 + (embed)0.00366
# Epoch 135 (train)27.3s: train loss = 0.00731 = (mf)0.00367 + (embed)0.00364
# Epoch 136 (train)27.6s: train loss = 0.00729 = (mf)0.00366 + (embed)0.00363
# Epoch 137 (train)27.6s: train loss = 0.00729 = (mf)0.00367 + (embed)0.00361
# Epoch 138 (train)27.8s: train loss = 0.00720 = (mf)0.00360 + (embed)0.00360
# Epoch 139 (train)27.7s: train loss = 0.00714 = (mf)0.00356 + (embed)0.00358
# Epoch 140 (train)27.7s + (eval)10.0s: train loss = 0.00707 = (mf)0.00350 + (embed)0.00357, recall = 0.02806, ndcg = 0.01968, precision = 0.00737, map = 0.01203
# Epoch 141 (train)27.4s: train loss = 0.00701 = (mf)0.00345 + (embed)0.00356
# Epoch 142 (train)27.5s: train loss = 0.00692 = (mf)0.00338 + (embed)0.00354
# Epoch 143 (train)27.8s: train loss = 0.00688 = (mf)0.00336 + (embed)0.00352
# Epoch 144 (train)27.8s: train loss = 0.00691 = (mf)0.00339 + (embed)0.00351
# Epoch 145 (train)27.8s: train loss = 0.00677 = (mf)0.00328 + (embed)0.00350
# Epoch 146 (train)27.7s: train loss = 0.00674 = (mf)0.00326 + (embed)0.00348
# Epoch 147 (train)27.6s: train loss = 0.00670 = (mf)0.00324 + (embed)0.00347
# Epoch 148 (train)27.8s: train loss = 0.00662 = (mf)0.00317 + (embed)0.00345
# Epoch 149 (train)27.6s: train loss = 0.00659 = (mf)0.00315 + (embed)0.00344
# Epoch 150 (train)27.8s + (eval)10.2s: train loss = 0.00661 = (mf)0.00319 + (embed)0.00342, recall = 0.02849, ndcg = 0.01983, precision = 0.00744, map = 0.01200
# Epoch 151 (train)27.5s: train loss = 0.00646 = (mf)0.00305 + (embed)0.00341
# Epoch 152 (train)27.7s: train loss = 0.00645 = (mf)0.00306 + (embed)0.00339
# Epoch 153 (train)27.6s: train loss = 0.00636 = (mf)0.00298 + (embed)0.00338
# Epoch 154 (train)27.5s: train loss = 0.00634 = (mf)0.00298 + (embed)0.00337
# Epoch 155 (train)27.7s: train loss = 0.00634 = (mf)0.00299 + (embed)0.00335
# Epoch 156 (train)27.8s: train loss = 0.00628 = (mf)0.00294 + (embed)0.00334
# Epoch 157 (train)27.8s: train loss = 0.00623 = (mf)0.00291 + (embed)0.00332
# Epoch 158 (train)27.5s: train loss = 0.00621 = (mf)0.00291 + (embed)0.00331
# Epoch 159 (train)27.7s: train loss = 0.00625 = (mf)0.00295 + (embed)0.00329
# Epoch 160 (train)27.5s + (eval)9.9s: train loss = 0.00615 = (mf)0.00287 + (embed)0.00328, recall = 0.02897, ndcg = 0.02013, precision = 0.00756, map = 0.01224
# Epoch 161 (train)27.0s: train loss = 0.00603 = (mf)0.00276 + (embed)0.00326
# Epoch 162 (train)26.7s: train loss = 0.00606 = (mf)0.00281 + (embed)0.00325
# Epoch 163 (train)27.0s: train loss = 0.00596 = (mf)0.00272 + (embed)0.00324
# Epoch 164 (train)27.1s: train loss = 0.00596 = (mf)0.00274 + (embed)0.00322
# Epoch 165 (train)26.9s: train loss = 0.00600 = (mf)0.00279 + (embed)0.00321
# Epoch 166 (train)27.0s: train loss = 0.00586 = (mf)0.00266 + (embed)0.00319
# Epoch 167 (train)26.9s: train loss = 0.00586 = (mf)0.00267 + (embed)0.00318
# Epoch 168 (train)26.9s: train loss = 0.00583 = (mf)0.00266 + (embed)0.00317
# Epoch 169 (train)26.8s: train loss = 0.00579 = (mf)0.00264 + (embed)0.00316
# Epoch 170 (train)27.0s + (eval)10.2s: train loss = 0.00574 = (mf)0.00260 + (embed)0.00314, recall = 0.02934, ndcg = 0.02029, precision = 0.00763, map = 0.01230
# Epoch 171 (train)26.9s: train loss = 0.00574 = (mf)0.00261 + (embed)0.00313
# Epoch 172 (train)26.9s: train loss = 0.00560 = (mf)0.00248 + (embed)0.00312
# Epoch 173 (train)27.0s: train loss = 0.00568 = (mf)0.00258 + (embed)0.00311
# Epoch 174 (train)27.1s: train loss = 0.00564 = (mf)0.00255 + (embed)0.00309
# Epoch 175 (train)27.4s: train loss = 0.00555 = (mf)0.00247 + (embed)0.00308
# Epoch 176 (train)27.2s: train loss = 0.00557 = (mf)0.00250 + (embed)0.00307
# Epoch 177 (train)27.0s: train loss = 0.00545 = (mf)0.00240 + (embed)0.00306
# Epoch 178 (train)26.9s: train loss = 0.00552 = (mf)0.00248 + (embed)0.00304
# Epoch 179 (train)27.2s: train loss = 0.00544 = (mf)0.00241 + (embed)0.00303
# Epoch 180 (train)26.9s + (eval)9.9s: train loss = 0.00540 = (mf)0.00238 + (embed)0.00302, recall = 0.02924, ndcg = 0.02036, precision = 0.00766, map = 0.01236
# Epoch 181 (train)26.6s: train loss = 0.00542 = (mf)0.00241 + (embed)0.00301
# Epoch 182 (train)25.1s: train loss = 0.00538 = (mf)0.00239 + (embed)0.00300
# Epoch 183 (train)25.1s: train loss = 0.00531 = (mf)0.00232 + (embed)0.00298
# Epoch 184 (train)25.5s: train loss = 0.00532 = (mf)0.00234 + (embed)0.00298
# Epoch 185 (train)25.5s: train loss = 0.00519 = (mf)0.00222 + (embed)0.00296
# Epoch 186 (train)25.6s: train loss = 0.00516 = (mf)0.00221 + (embed)0.00295
# Epoch 187 (train)25.1s: train loss = 0.00518 = (mf)0.00224 + (embed)0.00294
# Epoch 188 (train)24.9s: train loss = 0.00522 = (mf)0.00229 + (embed)0.00293
# Epoch 189 (train)25.0s: train loss = 0.00511 = (mf)0.00219 + (embed)0.00292
# Epoch 190 (train)24.9s + (eval)9.9s: train loss = 0.00509 = (mf)0.00219 + (embed)0.00291, recall = 0.02909, ndcg = 0.02040, precision = 0.00767, map = 0.01243
# Epoch 191 (train)24.8s: train loss = 0.00507 = (mf)0.00218 + (embed)0.00290
# Epoch 192 (train)24.9s: train loss = 0.00505 = (mf)0.00216 + (embed)0.00288
# Epoch 193 (train)24.7s: train loss = 0.00504 = (mf)0.00216 + (embed)0.00288
# Epoch 194 (train)24.8s: train loss = 0.00501 = (mf)0.00214 + (embed)0.00287
# Epoch 195 (train)25.1s: train loss = 0.00499 = (mf)0.00213 + (embed)0.00285
# Epoch 196 (train)25.1s: train loss = 0.00495 = (mf)0.00210 + (embed)0.00284
# Epoch 197 (train)24.7s: train loss = 0.00494 = (mf)0.00211 + (embed)0.00283
# Epoch 198 (train)24.8s: train loss = 0.00488 = (mf)0.00205 + (embed)0.00282
# Epoch 199 (train)24.9s: train loss = 0.00485 = (mf)0.00204 + (embed)0.00281
# Save model to path /home/wakatsuki/kaggle/h-and-m-personalized-fashion-recommendations/output/epoch_200
# Epoch 200 (train)24.9s + (eval)10.0s: train loss = 0.00483 = (mf)0.00203 + (embed)0.00281, recall = 0.02913, ndcg = 0.02030, precision = 0.00759, map = 0.01238
# Epoch 201 (train)24.9s: train loss = 0.00490 = (mf)0.00211 + (embed)0.00280
# Epoch 202 (train)24.7s: train loss = 0.00482 = (mf)0.00203 + (embed)0.00279
# Epoch 203 (train)24.8s: train loss = 0.00486 = (mf)0.00209 + (embed)0.00278
# Epoch 204 (train)24.9s: train loss = 0.00481 = (mf)0.00205 + (embed)0.00277
# Epoch 205 (train)25.0s: train loss = 0.00474 = (mf)0.00199 + (embed)0.00276
# Epoch 206 (train)24.9s: train loss = 0.00470 = (mf)0.00195 + (embed)0.00275
# Epoch 207 (train)25.0s: train loss = 0.00470 = (mf)0.00196 + (embed)0.00274
# Epoch 208 (train)24.8s: train loss = 0.00465 = (mf)0.00191 + (embed)0.00273
# Epoch 209 (train)24.8s: train loss = 0.00469 = (mf)0.00197 + (embed)0.00272
# Epoch 210 (train)24.9s + (eval)10.0s: train loss = 0.00466 = (mf)0.00194 + (embed)0.00272, recall = 0.02938, ndcg = 0.02047, precision = 0.00771, map = 0.01246
# Epoch 211 (train)24.8s: train loss = 0.00461 = (mf)0.00190 + (embed)0.00271
# Epoch 212 (train)24.8s: train loss = 0.00461 = (mf)0.00190 + (embed)0.00270
# Epoch 213 (train)24.8s: train loss = 0.00458 = (mf)0.00189 + (embed)0.00269
# Epoch 214 (train)25.0s: train loss = 0.00458 = (mf)0.00189 + (embed)0.00268
# Epoch 215 (train)24.8s: train loss = 0.00455 = (mf)0.00188 + (embed)0.00268
# Epoch 216 (train)25.1s: train loss = 0.00457 = (mf)0.00190 + (embed)0.00267
# Epoch 217 (train)24.9s: train loss = 0.00450 = (mf)0.00185 + (embed)0.00266
# Epoch 218 (train)24.8s: train loss = 0.00450 = (mf)0.00184 + (embed)0.00265
# Epoch 219 (train)24.9s: train loss = 0.00446 = (mf)0.00181 + (embed)0.00265
# Epoch 220 (train)25.1s + (eval)10.2s: train loss = 0.00447 = (mf)0.00183 + (embed)0.00264, recall = 0.02932, ndcg = 0.02040, precision = 0.00766, map = 0.01238
# Epoch 221 (train)24.9s: train loss = 0.00450 = (mf)0.00187 + (embed)0.00263
# Epoch 222 (train)24.6s: train loss = 0.00447 = (mf)0.00185 + (embed)0.00262
# Epoch 223 (train)24.9s: train loss = 0.00440 = (mf)0.00178 + (embed)0.00262
# Epoch 224 (train)24.7s: train loss = 0.00446 = (mf)0.00185 + (embed)0.00261
# Epoch 225 (train)25.0s: train loss = 0.00436 = (mf)0.00176 + (embed)0.00260
# Epoch 226 (train)24.6s: train loss = 0.00435 = (mf)0.00175 + (embed)0.00260
# Epoch 227 (train)24.9s: train loss = 0.00432 = (mf)0.00173 + (embed)0.00259
# Epoch 228 (train)24.8s: train loss = 0.00429 = (mf)0.00171 + (embed)0.00258
# Epoch 229 (train)24.7s: train loss = 0.00430 = (mf)0.00173 + (embed)0.00258
# Epoch 230 (train)24.8s + (eval)10.0s: train loss = 0.00425 = (mf)0.00168 + (embed)0.00257, recall = 0.02936, ndcg = 0.02051, precision = 0.00767, map = 0.01255
# Epoch 231 (train)25.1s: train loss = 0.00428 = (mf)0.00171 + (embed)0.00256
# Epoch 232 (train)24.9s: train loss = 0.00422 = (mf)0.00166 + (embed)0.00256
# Epoch 233 (train)25.1s: train loss = 0.00420 = (mf)0.00165 + (embed)0.00255
# Epoch 234 (train)25.3s: train loss = 0.00419 = (mf)0.00164 + (embed)0.00255
# Epoch 235 (train)24.9s: train loss = 0.00420 = (mf)0.00166 + (embed)0.00254
# Epoch 236 (train)24.7s: train loss = 0.00417 = (mf)0.00164 + (embed)0.00253
# Epoch 237 (train)25.0s: train loss = 0.00421 = (mf)0.00168 + (embed)0.00253
# Epoch 238 (train)25.1s: train loss = 0.00418 = (mf)0.00166 + (embed)0.00252
# Epoch 239 (train)25.0s: train loss = 0.00412 = (mf)0.00160 + (embed)0.00252
# Epoch 240 (train)24.7s + (eval)10.1s: train loss = 0.00414 = (mf)0.00163 + (embed)0.00251, recall = 0.02944, ndcg = 0.02053, precision = 0.00769, map = 0.01250
# Epoch 241 (train)24.8s: train loss = 0.00410 = (mf)0.00160 + (embed)0.00251
# Epoch 242 (train)25.0s: train loss = 0.00410 = (mf)0.00160 + (embed)0.00250
# Epoch 243 (train)24.7s: train loss = 0.00409 = (mf)0.00159 + (embed)0.00250
# Epoch 244 (train)24.8s: train loss = 0.00408 = (mf)0.00159 + (embed)0.00249
# Epoch 245 (train)24.7s: train loss = 0.00411 = (mf)0.00162 + (embed)0.00248
# Epoch 246 (train)24.7s: train loss = 0.00409 = (mf)0.00161 + (embed)0.00248
# Epoch 247 (train)24.9s: train loss = 0.00406 = (mf)0.00159 + (embed)0.00247
# Epoch 248 (train)24.8s: train loss = 0.00404 = (mf)0.00157 + (embed)0.00247
# Epoch 249 (train)24.8s: train loss = 0.00402 = (mf)0.00155 + (embed)0.00247
# Epoch 250 (train)24.9s + (eval)10.1s: train loss = 0.00402 = (mf)0.00156 + (embed)0.00246, recall = 0.02934, ndcg = 0.02038, precision = 0.00766, map = 0.01237
# Epoch 251 (train)25.0s: train loss = 0.00398 = (mf)0.00152 + (embed)0.00246
# Epoch 252 (train)25.1s: train loss = 0.00396 = (mf)0.00151 + (embed)0.00245
# Epoch 253 (train)25.0s: train loss = 0.00400 = (mf)0.00155 + (embed)0.00245
# Epoch 254 (train)25.1s: train loss = 0.00392 = (mf)0.00147 + (embed)0.00244
# Epoch 255 (train)25.0s: train loss = 0.00395 = (mf)0.00151 + (embed)0.00244
# Epoch 256 (train)25.0s: train loss = 0.00392 = (mf)0.00148 + (embed)0.00243
# Epoch 257 (train)24.9s: train loss = 0.00395 = (mf)0.00152 + (embed)0.00243
# Epoch 258 (train)25.0s: train loss = 0.00392 = (mf)0.00149 + (embed)0.00243
# Epoch 259 (train)25.4s: train loss = 0.00386 = (mf)0.00144 + (embed)0.00242
# Epoch 260 (train)25.7s + (eval)10.1s: train loss = 0.00391 = (mf)0.00150 + (embed)0.00242, recall = 0.02935, ndcg = 0.02058, precision = 0.00769, map = 0.01259
# Epoch 261 (train)25.7s: train loss = 0.00390 = (mf)0.00149 + (embed)0.00241
# Epoch 262 (train)25.4s: train loss = 0.00386 = (mf)0.00145 + (embed)0.00241
# Epoch 263 (train)24.6s: train loss = 0.00388 = (mf)0.00148 + (embed)0.00241
# Epoch 264 (train)24.1s: train loss = 0.00385 = (mf)0.00145 + (embed)0.00240
# Epoch 265 (train)24.5s: train loss = 0.00388 = (mf)0.00148 + (embed)0.00240
# Epoch 266 (train)24.5s: train loss = 0.00381 = (mf)0.00142 + (embed)0.00239
# Epoch 267 (train)24.7s: train loss = 0.00384 = (mf)0.00145 + (embed)0.00239
# Epoch 268 (train)24.5s: train loss = 0.00377 = (mf)0.00139 + (embed)0.00239
# Epoch 269 (train)24.4s: train loss = 0.00381 = (mf)0.00143 + (embed)0.00238
# Epoch 270 (train)24.6s + (eval)10.0s: train loss = 0.00376 = (mf)0.00138 + (embed)0.00238, recall = 0.02946, ndcg = 0.02062, precision = 0.00774, map = 0.01259
# Epoch 271 (train)24.5s: train loss = 0.00378 = (mf)0.00141 + (embed)0.00238
# Epoch 272 (train)24.0s: train loss = 0.00376 = (mf)0.00138 + (embed)0.00237
# Epoch 273 (train)23.9s: train loss = 0.00376 = (mf)0.00139 + (embed)0.00237
# Epoch 274 (train)24.1s: train loss = 0.00376 = (mf)0.00139 + (embed)0.00237
# Epoch 275 (train)24.7s: train loss = 0.00373 = (mf)0.00137 + (embed)0.00236
# Epoch 276 (train)24.6s: train loss = 0.00371 = (mf)0.00135 + (embed)0.00236
# Epoch 277 (train)24.8s: train loss = 0.00374 = (mf)0.00138 + (embed)0.00236
# Epoch 278 (train)23.9s: train loss = 0.00371 = (mf)0.00136 + (embed)0.00236
# Epoch 279 (train)23.8s: train loss = 0.00370 = (mf)0.00135 + (embed)0.00235
# Epoch 280 (train)23.7s + (eval)9.9s: train loss = 0.00368 = (mf)0.00133 + (embed)0.00235, recall = 0.02949, ndcg = 0.02069, precision = 0.00775, map = 0.01261
# Epoch 281 (train)24.3s: train loss = 0.00367 = (mf)0.00132 + (embed)0.00235
# Epoch 282 (train)24.4s: train loss = 0.00372 = (mf)0.00138 + (embed)0.00234
# Epoch 283 (train)24.5s: train loss = 0.00366 = (mf)0.00132 + (embed)0.00234
# Epoch 284 (train)24.6s: train loss = 0.00365 = (mf)0.00132 + (embed)0.00234
# Epoch 285 (train)24.2s: train loss = 0.00367 = (mf)0.00133 + (embed)0.00234
# Epoch 286 (train)24.4s: train loss = 0.00364 = (mf)0.00130 + (embed)0.00233
# Epoch 287 (train)23.9s: train loss = 0.00365 = (mf)0.00132 + (embed)0.00233
# Epoch 288 (train)24.1s: train loss = 0.00366 = (mf)0.00133 + (embed)0.00233
# Epoch 289 (train)24.1s: train loss = 0.00362 = (mf)0.00130 + (embed)0.00232
# Epoch 290 (train)23.9s + (eval)10.1s: train loss = 0.00363 = (mf)0.00131 + (embed)0.00232, recall = 0.02949, ndcg = 0.02070, precision = 0.00772, map = 0.01262
# Epoch 291 (train)24.0s: train loss = 0.00360 = (mf)0.00128 + (embed)0.00232
# Epoch 292 (train)25.1s: train loss = 0.00362 = (mf)0.00131 + (embed)0.00232
# Epoch 293 (train)25.0s: train loss = 0.00361 = (mf)0.00130 + (embed)0.00231
# Epoch 294 (train)24.9s: train loss = 0.00355 = (mf)0.00124 + (embed)0.00231
# Epoch 295 (train)24.3s: train loss = 0.00361 = (mf)0.00130 + (embed)0.00231
# Epoch 296 (train)24.9s: train loss = 0.00357 = (mf)0.00126 + (embed)0.00231
# Epoch 297 (train)24.8s: train loss = 0.00359 = (mf)0.00128 + (embed)0.00231
# Epoch 298 (train)24.2s: train loss = 0.00356 = (mf)0.00126 + (embed)0.00230
# Epoch 299 (train)24.5s: train loss = 0.00358 = (mf)0.00128 + (embed)0.00230
# Save model to path /home/wakatsuki/kaggle/h-and-m-personalized-fashion-recommendations/output/epoch_300
# Epoch 300 (train)25.0s + (eval)10.3s: train loss = 0.00354 = (mf)0.00124 + (embed)0.00230, recall = 0.02952, ndcg = 0.02074, precision = 0.00780, map = 0.01265
# Epoch 301 (train)24.4s: train loss = 0.00352 = (mf)0.00122 + (embed)0.00230
# Epoch 302 (train)24.9s: train loss = 0.00353 = (mf)0.00124 + (embed)0.00230
# Epoch 303 (train)24.4s: train loss = 0.00354 = (mf)0.00125 + (embed)0.00229
# Epoch 304 (train)25.6s: train loss = 0.00348 = (mf)0.00118 + (embed)0.00229
# Epoch 305 (train)25.7s: train loss = 0.00353 = (mf)0.00124 + (embed)0.00229
# Epoch 306 (train)25.7s: train loss = 0.00353 = (mf)0.00124 + (embed)0.00229
# Epoch 307 (train)25.7s: train loss = 0.00348 = (mf)0.00119 + (embed)0.00229
# Epoch 308 (train)25.7s: train loss = 0.00350 = (mf)0.00121 + (embed)0.00228
# Epoch 309 (train)25.7s: train loss = 0.00346 = (mf)0.00118 + (embed)0.00228
# Epoch 310 (train)25.7s + (eval)10.2s: train loss = 0.00349 = (mf)0.00121 + (embed)0.00228, recall = 0.02977, ndcg = 0.02092, precision = 0.00784, map = 0.01278
# Epoch 311 (train)25.9s: train loss = 0.00351 = (mf)0.00123 + (embed)0.00228
# Epoch 312 (train)25.8s: train loss = 0.00350 = (mf)0.00122 + (embed)0.00228
# Epoch 313 (train)25.9s: train loss = 0.00350 = (mf)0.00122 + (embed)0.00228
# Epoch 314 (train)25.7s: train loss = 0.00347 = (mf)0.00119 + (embed)0.00227
# Epoch 315 (train)25.8s: train loss = 0.00344 = (mf)0.00117 + (embed)0.00227
# Epoch 316 (train)25.7s: train loss = 0.00345 = (mf)0.00118 + (embed)0.00227
# Epoch 317 (train)25.6s: train loss = 0.00344 = (mf)0.00117 + (embed)0.00227
# Epoch 318 (train)25.6s: train loss = 0.00345 = (mf)0.00119 + (embed)0.00227
# Epoch 319 (train)25.7s: train loss = 0.00340 = (mf)0.00113 + (embed)0.00227
# Epoch 320 (train)26.1s + (eval)10.1s: train loss = 0.00342 = (mf)0.00116 + (embed)0.00226, recall = 0.02969, ndcg = 0.02086, precision = 0.00779, map = 0.01276
# Epoch 321 (train)25.8s: train loss = 0.00341 = (mf)0.00115 + (embed)0.00226
# Epoch 322 (train)25.9s: train loss = 0.00340 = (mf)0.00113 + (embed)0.00226
# Epoch 323 (train)25.9s: train loss = 0.00343 = (mf)0.00117 + (embed)0.00226
# Epoch 324 (train)25.9s: train loss = 0.00342 = (mf)0.00116 + (embed)0.00226
# Epoch 325 (train)25.7s: train loss = 0.00345 = (mf)0.00119 + (embed)0.00226
# Epoch 326 (train)25.7s: train loss = 0.00339 = (mf)0.00113 + (embed)0.00226
# Epoch 327 (train)25.6s: train loss = 0.00339 = (mf)0.00113 + (embed)0.00225
# Epoch 328 (train)25.7s: train loss = 0.00337 = (mf)0.00112 + (embed)0.00225
# Epoch 329 (train)25.7s: train loss = 0.00336 = (mf)0.00111 + (embed)0.00225
# Epoch 330 (train)25.8s + (eval)10.1s: train loss = 0.00335 = (mf)0.00110 + (embed)0.00225, recall = 0.02992, ndcg = 0.02085, precision = 0.00781, map = 0.01269
# Epoch 331 (train)25.9s: train loss = 0.00336 = (mf)0.00112 + (embed)0.00225
# Epoch 332 (train)25.9s: train loss = 0.00339 = (mf)0.00114 + (embed)0.00225
# Epoch 333 (train)25.8s: train loss = 0.00332 = (mf)0.00107 + (embed)0.00225
# Epoch 334 (train)25.7s: train loss = 0.00336 = (mf)0.00112 + (embed)0.00224
# Epoch 335 (train)26.2s: train loss = 0.00334 = (mf)0.00109 + (embed)0.00224
# Epoch 336 (train)25.8s: train loss = 0.00332 = (mf)0.00108 + (embed)0.00224
# Epoch 337 (train)25.7s: train loss = 0.00339 = (mf)0.00115 + (embed)0.00224
# Epoch 338 (train)25.6s: train loss = 0.00335 = (mf)0.00111 + (embed)0.00224
# Epoch 339 (train)25.7s: train loss = 0.00330 = (mf)0.00106 + (embed)0.00224
# Epoch 340 (train)25.9s + (eval)10.4s: train loss = 0.00331 = (mf)0.00107 + (embed)0.00224, recall = 0.02975, ndcg = 0.02085, precision = 0.00781, map = 0.01273
# Epoch 341 (train)25.8s: train loss = 0.00331 = (mf)0.00108 + (embed)0.00224
# Epoch 342 (train)26.0s: train loss = 0.00333 = (mf)0.00109 + (embed)0.00224
# Epoch 343 (train)25.8s: train loss = 0.00331 = (mf)0.00108 + (embed)0.00223
# Epoch 344 (train)25.8s: train loss = 0.00329 = (mf)0.00106 + (embed)0.00223
# Epoch 345 (train)25.9s: train loss = 0.00329 = (mf)0.00106 + (embed)0.00223
# Epoch 346 (train)25.7s: train loss = 0.00328 = (mf)0.00105 + (embed)0.00223
# Epoch 347 (train)25.5s: train loss = 0.00333 = (mf)0.00110 + (embed)0.00223
# Epoch 348 (train)25.7s: train loss = 0.00328 = (mf)0.00105 + (embed)0.00223
# Epoch 349 (train)25.6s: train loss = 0.00332 = (mf)0.00110 + (embed)0.00223
# Epoch 350 (train)25.7s + (eval)10.0s: train loss = 0.00329 = (mf)0.00107 + (embed)0.00223, recall = 0.02994, ndcg = 0.02092, precision = 0.00785, map = 0.01274
# Epoch 351 (train)25.7s: train loss = 0.00324 = (mf)0.00102 + (embed)0.00223
# Epoch 352 (train)25.7s: train loss = 0.00328 = (mf)0.00105 + (embed)0.00222
# Epoch 353 (train)26.1s: train loss = 0.00328 = (mf)0.00105 + (embed)0.00222
# Epoch 354 (train)25.9s: train loss = 0.00327 = (mf)0.00105 + (embed)0.00222
# Epoch 355 (train)25.8s: train loss = 0.00325 = (mf)0.00103 + (embed)0.00222
# Epoch 356 (train)25.8s: train loss = 0.00328 = (mf)0.00105 + (embed)0.00222
# Epoch 357 (train)25.8s: train loss = 0.00322 = (mf)0.00100 + (embed)0.00222
# Epoch 358 (train)25.6s: train loss = 0.00322 = (mf)0.00100 + (embed)0.00222
# Epoch 359 (train)25.9s: train loss = 0.00326 = (mf)0.00104 + (embed)0.00222
# Epoch 360 (train)25.7s + (eval)10.1s: train loss = 0.00322 = (mf)0.00100 + (embed)0.00222, recall = 0.02957, ndcg = 0.02084, precision = 0.00774, map = 0.01277
# Epoch 361 (train)25.9s: train loss = 0.00324 = (mf)0.00102 + (embed)0.00222
# Epoch 362 (train)25.6s: train loss = 0.00323 = (mf)0.00101 + (embed)0.00222
# Epoch 363 (train)25.8s: train loss = 0.00322 = (mf)0.00101 + (embed)0.00221
# Epoch 364 (train)26.0s: train loss = 0.00327 = (mf)0.00105 + (embed)0.00222
# Epoch 365 (train)25.8s: train loss = 0.00322 = (mf)0.00101 + (embed)0.00222
# Epoch 366 (train)25.7s: train loss = 0.00322 = (mf)0.00100 + (embed)0.00221
# Epoch 367 (train)25.9s: train loss = 0.00319 = (mf)0.00098 + (embed)0.00221
# Epoch 368 (train)25.8s: train loss = 0.00322 = (mf)0.00101 + (embed)0.00221
# Epoch 369 (train)25.8s: train loss = 0.00320 = (mf)0.00099 + (embed)0.00221
# Epoch 370 (train)25.8s + (eval)10.1s: train loss = 0.00321 = (mf)0.00100 + (embed)0.00221, recall = 0.02977, ndcg = 0.02090, precision = 0.00780, map = 0.01277
# Epoch 371 (train)25.8s: train loss = 0.00315 = (mf)0.00094 + (embed)0.00221
# Epoch 372 (train)25.7s: train loss = 0.00319 = (mf)0.00098 + (embed)0.00221
# Epoch 373 (train)25.9s: train loss = 0.00319 = (mf)0.00098 + (embed)0.00221
# Epoch 374 (train)25.7s: train loss = 0.00322 = (mf)0.00101 + (embed)0.00221
# Epoch 375 (train)25.7s: train loss = 0.00317 = (mf)0.00096 + (embed)0.00221
# Epoch 376 (train)25.8s: train loss = 0.00317 = (mf)0.00096 + (embed)0.00221
# Epoch 377 (train)25.7s: train loss = 0.00317 = (mf)0.00096 + (embed)0.00221
# Epoch 378 (train)25.6s: train loss = 0.00322 = (mf)0.00102 + (embed)0.00220
# Epoch 379 (train)25.6s: train loss = 0.00318 = (mf)0.00098 + (embed)0.00220
# Epoch 380 (train)25.7s + (eval)10.2s: train loss = 0.00316 = (mf)0.00095 + (embed)0.00220, recall = 0.02992, ndcg = 0.02106, precision = 0.00781, map = 0.01291
# Epoch 381 (train)25.8s: train loss = 0.00315 = (mf)0.00095 + (embed)0.00220
# Epoch 382 (train)25.9s: train loss = 0.00314 = (mf)0.00094 + (embed)0.00220
# Epoch 383 (train)25.9s: train loss = 0.00316 = (mf)0.00096 + (embed)0.00220
# Epoch 384 (train)25.9s: train loss = 0.00317 = (mf)0.00097 + (embed)0.00220
# Epoch 385 (train)25.8s: train loss = 0.00315 = (mf)0.00095 + (embed)0.00220
# Epoch 386 (train)25.7s: train loss = 0.00318 = (mf)0.00098 + (embed)0.00220
# Epoch 387 (train)25.7s: train loss = 0.00314 = (mf)0.00094 + (embed)0.00220
# Epoch 388 (train)25.6s: train loss = 0.00313 = (mf)0.00093 + (embed)0.00220
# Epoch 389 (train)25.6s: train loss = 0.00314 = (mf)0.00094 + (embed)0.00220
# Epoch 390 (train)25.8s + (eval)10.2s: train loss = 0.00317 = (mf)0.00097 + (embed)0.00220, recall = 0.02945, ndcg = 0.02099, precision = 0.00774, map = 0.01294
# Epoch 391 (train)25.9s: train loss = 0.00314 = (mf)0.00094 + (embed)0.00220
# Epoch 392 (train)25.9s: train loss = 0.00315 = (mf)0.00095 + (embed)0.00220
# Epoch 393 (train)25.8s: train loss = 0.00313 = (mf)0.00094 + (embed)0.00220
# Epoch 394 (train)25.8s: train loss = 0.00311 = (mf)0.00092 + (embed)0.00220
# Epoch 395 (train)25.7s: train loss = 0.00312 = (mf)0.00092 + (embed)0.00220
# Epoch 396 (train)25.7s: train loss = 0.00311 = (mf)0.00092 + (embed)0.00219
# Epoch 397 (train)25.6s: train loss = 0.00313 = (mf)0.00094 + (embed)0.00219
# Epoch 398 (train)25.8s: train loss = 0.00311 = (mf)0.00092 + (embed)0.00219
# Epoch 399 (train)25.7s: train loss = 0.00310 = (mf)0.00090 + (embed)0.00219
# Save model to path /home/wakatsuki/kaggle/h-and-m-personalized-fashion-recommendations/output/epoch_400
# Epoch 400 (train)25.9s + (eval)10.3s: train loss = 0.00309 = (mf)0.00090 + (embed)0.00219, recall = 0.03012, ndcg = 0.02120, precision = 0.00786, map = 0.01300
# Epoch 401 (train)25.8s: train loss = 0.00312 = (mf)0.00093 + (embed)0.00219
# Epoch 402 (train)25.9s: train loss = 0.00314 = (mf)0.00095 + (embed)0.00219
# Epoch 403 (train)25.9s: train loss = 0.00309 = (mf)0.00090 + (embed)0.00219
# Epoch 404 (train)26.0s: train loss = 0.00310 = (mf)0.00091 + (embed)0.00219
# Epoch 405 (train)25.7s: train loss = 0.00307 = (mf)0.00088 + (embed)0.00219
# Epoch 406 (train)25.9s: train loss = 0.00310 = (mf)0.00091 + (embed)0.00219
# Epoch 407 (train)25.8s: train loss = 0.00309 = (mf)0.00090 + (embed)0.00219
# Epoch 408 (train)26.0s: train loss = 0.00311 = (mf)0.00092 + (embed)0.00219
# Epoch 409 (train)26.0s: train loss = 0.00306 = (mf)0.00087 + (embed)0.00219
# Epoch 410 (train)25.6s + (eval)10.2s: train loss = 0.00307 = (mf)0.00089 + (embed)0.00219, recall = 0.03019, ndcg = 0.02119, precision = 0.00786, map = 0.01299
# Epoch 411 (train)25.6s: train loss = 0.00308 = (mf)0.00089 + (embed)0.00219
# Epoch 412 (train)25.7s: train loss = 0.00307 = (mf)0.00088 + (embed)0.00219
# Epoch 413 (train)26.0s: train loss = 0.00306 = (mf)0.00088 + (embed)0.00219
# Epoch 414 (train)25.8s: train loss = 0.00307 = (mf)0.00089 + (embed)0.00219
# Epoch 415 (train)25.7s: train loss = 0.00307 = (mf)0.00089 + (embed)0.00219
# Epoch 416 (train)25.7s: train loss = 0.00307 = (mf)0.00089 + (embed)0.00219
# Epoch 417 (train)25.6s: train loss = 0.00310 = (mf)0.00092 + (embed)0.00218
# Epoch 418 (train)25.7s: train loss = 0.00310 = (mf)0.00091 + (embed)0.00218
# Epoch 419 (train)25.5s: train loss = 0.00305 = (mf)0.00087 + (embed)0.00218
# Epoch 420 (train)26.0s + (eval)10.2s: train loss = 0.00306 = (mf)0.00088 + (embed)0.00218, recall = 0.03024, ndcg = 0.02120, precision = 0.00785, map = 0.01297
# Epoch 421 (train)25.7s: train loss = 0.00308 = (mf)0.00090 + (embed)0.00218
# Epoch 422 (train)25.7s: train loss = 0.00307 = (mf)0.00089 + (embed)0.00218
# Epoch 423 (train)25.9s: train loss = 0.00307 = (mf)0.00089 + (embed)0.00218
# Epoch 424 (train)25.7s: train loss = 0.00306 = (mf)0.00088 + (embed)0.00218
# Epoch 425 (train)26.0s: train loss = 0.00306 = (mf)0.00087 + (embed)0.00218
# Epoch 426 (train)27.0s: train loss = 0.00306 = (mf)0.00088 + (embed)0.00218
# Epoch 427 (train)25.8s: train loss = 0.00305 = (mf)0.00087 + (embed)0.00218
# Epoch 428 (train)26.8s: train loss = 0.00305 = (mf)0.00087 + (embed)0.00218
# Epoch 429 (train)26.7s: train loss = 0.00305 = (mf)0.00087 + (embed)0.00218
# Epoch 430 (train)25.9s + (eval)10.0s: train loss = 0.00309 = (mf)0.00091 + (embed)0.00218, recall = 0.03029, ndcg = 0.02120, precision = 0.00787, map = 0.01297
# Epoch 431 (train)26.3s: train loss = 0.00308 = (mf)0.00090 + (embed)0.00218
# Epoch 432 (train)26.0s: train loss = 0.00303 = (mf)0.00086 + (embed)0.00218
# Epoch 433 (train)26.6s: train loss = 0.00304 = (mf)0.00086 + (embed)0.00218
# Epoch 434 (train)27.1s: train loss = 0.00305 = (mf)0.00087 + (embed)0.00218
# Epoch 435 (train)26.6s: train loss = 0.00304 = (mf)0.00086 + (embed)0.00218
# Epoch 436 (train)27.3s: train loss = 0.00303 = (mf)0.00085 + (embed)0.00218
# Epoch 437 (train)26.0s: train loss = 0.00304 = (mf)0.00087 + (embed)0.00218
# Epoch 438 (train)25.7s: train loss = 0.00303 = (mf)0.00085 + (embed)0.00218
# Epoch 439 (train)25.9s: train loss = 0.00304 = (mf)0.00086 + (embed)0.00218
# Epoch 440 (train)26.5s + (eval)10.1s: train loss = 0.00304 = (mf)0.00086 + (embed)0.00218, recall = 0.03003, ndcg = 0.02119, precision = 0.00783, map = 0.01301
# Epoch 441 (train)26.2s: train loss = 0.00305 = (mf)0.00087 + (embed)0.00218
# Epoch 442 (train)26.1s: train loss = 0.00302 = (mf)0.00085 + (embed)0.00218
# Epoch 443 (train)26.8s: train loss = 0.00299 = (mf)0.00081 + (embed)0.00218
# Epoch 444 (train)27.5s: train loss = 0.00302 = (mf)0.00084 + (embed)0.00218
# Epoch 445 (train)26.8s: train loss = 0.00297 = (mf)0.00079 + (embed)0.00218
# Epoch 446 (train)26.1s: train loss = 0.00303 = (mf)0.00085 + (embed)0.00217
# Epoch 447 (train)26.4s: train loss = 0.00299 = (mf)0.00081 + (embed)0.00218
# Epoch 448 (train)27.2s: train loss = 0.00300 = (mf)0.00083 + (embed)0.00217
# Epoch 449 (train)26.2s: train loss = 0.00304 = (mf)0.00086 + (embed)0.00218
# Epoch 450 (train)26.5s + (eval)10.3s: train loss = 0.00304 = (mf)0.00086 + (embed)0.00217, recall = 0.03034, ndcg = 0.02124, precision = 0.00786, map = 0.01299
# Epoch 451 (train)26.5s: train loss = 0.00299 = (mf)0.00082 + (embed)0.00217
# Epoch 452 (train)27.0s: train loss = 0.00299 = (mf)0.00081 + (embed)0.00217
# Epoch 453 (train)26.6s: train loss = 0.00300 = (mf)0.00083 + (embed)0.00217
# Epoch 454 (train)26.0s: train loss = 0.00300 = (mf)0.00083 + (embed)0.00217
# Epoch 455 (train)25.9s: train loss = 0.00302 = (mf)0.00085 + (embed)0.00217
# Epoch 456 (train)25.7s: train loss = 0.00299 = (mf)0.00082 + (embed)0.00217
# Epoch 457 (train)25.7s: train loss = 0.00302 = (mf)0.00084 + (embed)0.00217
# Epoch 458 (train)25.7s: train loss = 0.00303 = (mf)0.00086 + (embed)0.00217
# Epoch 459 (train)25.7s: train loss = 0.00303 = (mf)0.00086 + (embed)0.00217
# Epoch 460 (train)25.8s + (eval)10.3s: train loss = 0.00302 = (mf)0.00085 + (embed)0.00217, recall = 0.03007, ndcg = 0.02122, precision = 0.00781, map = 0.01304
# Epoch 461 (train)25.7s: train loss = 0.00297 = (mf)0.00080 + (embed)0.00217
# Epoch 462 (train)25.8s: train loss = 0.00301 = (mf)0.00083 + (embed)0.00217
# Epoch 463 (train)26.0s: train loss = 0.00299 = (mf)0.00082 + (embed)0.00217
# Epoch 464 (train)25.7s: train loss = 0.00299 = (mf)0.00082 + (embed)0.00217
# Epoch 465 (train)25.8s: train loss = 0.00298 = (mf)0.00081 + (embed)0.00217
# Epoch 466 (train)25.8s: train loss = 0.00299 = (mf)0.00082 + (embed)0.00217
# Epoch 467 (train)25.7s: train loss = 0.00298 = (mf)0.00081 + (embed)0.00217
# Epoch 468 (train)25.8s: train loss = 0.00298 = (mf)0.00081 + (embed)0.00217
# Epoch 469 (train)25.8s: train loss = 0.00299 = (mf)0.00082 + (embed)0.00217
# Epoch 470 (train)25.7s + (eval)10.1s: train loss = 0.00298 = (mf)0.00081 + (embed)0.00217, recall = 0.03026, ndcg = 0.02128, precision = 0.00785, map = 0.01304
# Epoch 471 (train)25.8s: train loss = 0.00300 = (mf)0.00083 + (embed)0.00217
# Epoch 472 (train)25.9s: train loss = 0.00295 = (mf)0.00078 + (embed)0.00217
# Epoch 473 (train)25.8s: train loss = 0.00301 = (mf)0.00083 + (embed)0.00217
# Epoch 474 (train)25.9s: train loss = 0.00297 = (mf)0.00080 + (embed)0.00217
# Epoch 475 (train)25.9s: train loss = 0.00295 = (mf)0.00079 + (embed)0.00217
# Epoch 476 (train)25.9s: train loss = 0.00300 = (mf)0.00082 + (embed)0.00217
# Epoch 477 (train)25.6s: train loss = 0.00300 = (mf)0.00083 + (embed)0.00217
# Epoch 478 (train)26.0s: train loss = 0.00297 = (mf)0.00081 + (embed)0.00217
# Epoch 479 (train)25.8s: train loss = 0.00298 = (mf)0.00081 + (embed)0.00217
# Epoch 480 (train)26.0s + (eval)10.3s: train loss = 0.00298 = (mf)0.00081 + (embed)0.00217, recall = 0.03044, ndcg = 0.02137, precision = 0.00787, map = 0.01314
# Epoch 481 (train)25.7s: train loss = 0.00294 = (mf)0.00077 + (embed)0.00217
# Epoch 482 (train)25.8s: train loss = 0.00294 = (mf)0.00078 + (embed)0.00217
# Epoch 483 (train)25.9s: train loss = 0.00294 = (mf)0.00077 + (embed)0.00217
# Epoch 484 (train)25.9s: train loss = 0.00293 = (mf)0.00077 + (embed)0.00217
# Epoch 485 (train)25.9s: train loss = 0.00297 = (mf)0.00080 + (embed)0.00217
# Epoch 486 (train)26.0s: train loss = 0.00296 = (mf)0.00080 + (embed)0.00217
# Epoch 487 (train)25.9s: train loss = 0.00296 = (mf)0.00079 + (embed)0.00217
# Epoch 488 (train)26.0s: train loss = 0.00296 = (mf)0.00079 + (embed)0.00217
# Epoch 489 (train)26.1s: train loss = 0.00294 = (mf)0.00077 + (embed)0.00217
# Epoch 490 (train)26.2s + (eval)10.1s: train loss = 0.00294 = (mf)0.00077 + (embed)0.00217, recall = 0.03064, ndcg = 0.02140, precision = 0.00788, map = 0.01312
# Epoch 491 (train)26.1s: train loss = 0.00294 = (mf)0.00078 + (embed)0.00217
# Epoch 492 (train)25.9s: train loss = 0.00295 = (mf)0.00079 + (embed)0.00217
# Epoch 493 (train)26.1s: train loss = 0.00295 = (mf)0.00078 + (embed)0.00217
# Epoch 494 (train)26.2s: train loss = 0.00291 = (mf)0.00075 + (embed)0.00217
# Epoch 495 (train)25.9s: train loss = 0.00294 = (mf)0.00077 + (embed)0.00217
# Epoch 496 (train)25.8s: train loss = 0.00295 = (mf)0.00079 + (embed)0.00216
# Epoch 497 (train)25.8s: train loss = 0.00295 = (mf)0.00079 + (embed)0.00217
# Epoch 498 (train)25.9s: train loss = 0.00295 = (mf)0.00078 + (embed)0.00217
# Epoch 499 (train)25.9s: train loss = 0.00293 = (mf)0.00077 + (embed)0.00216
# Save model to path /home/wakatsuki/kaggle/h-and-m-personalized-fashion-recommendations/output/epoch_500
# Epoch 500 (train)25.9s + (eval)10.6s: train loss = 0.00293 = (mf)0.00077 + (embed)0.00216, recall = 0.03065, ndcg = 0.02145, precision = 0.00793, map = 0.01315
# Epoch 501 (train)25.7s: train loss = 0.00293 = (mf)0.00077 + (embed)0.00216
# Epoch 502 (train)25.9s: train loss = 0.00291 = (mf)0.00075 + (embed)0.00216
# Epoch 503 (train)25.8s: train loss = 0.00294 = (mf)0.00077 + (embed)0.00216
# Epoch 504 (train)25.8s: train loss = 0.00290 = (mf)0.00073 + (embed)0.00217
# Epoch 505 (train)25.8s: train loss = 0.00294 = (mf)0.00078 + (embed)0.00216
# Epoch 506 (train)26.1s: train loss = 0.00294 = (mf)0.00077 + (embed)0.00216
# Epoch 507 (train)25.9s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216
# Epoch 508 (train)25.7s: train loss = 0.00294 = (mf)0.00077 + (embed)0.00216
# Epoch 509 (train)25.9s: train loss = 0.00288 = (mf)0.00072 + (embed)0.00216
# Epoch 510 (train)25.6s + (eval)10.1s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216, recall = 0.03056, ndcg = 0.02139, precision = 0.00791, map = 0.01312
# Epoch 511 (train)25.8s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216
# Epoch 512 (train)25.7s: train loss = 0.00292 = (mf)0.00075 + (embed)0.00216
# Epoch 513 (train)25.7s: train loss = 0.00293 = (mf)0.00077 + (embed)0.00216
# Epoch 514 (train)25.8s: train loss = 0.00291 = (mf)0.00075 + (embed)0.00216
# Epoch 515 (train)25.7s: train loss = 0.00289 = (mf)0.00072 + (embed)0.00216
# Epoch 516 (train)25.9s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216
# Epoch 517 (train)25.7s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216
# Epoch 518 (train)26.0s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216
# Epoch 519 (train)26.0s: train loss = 0.00288 = (mf)0.00072 + (embed)0.00216
# Epoch 520 (train)25.9s + (eval)10.1s: train loss = 0.00291 = (mf)0.00075 + (embed)0.00216, recall = 0.03034, ndcg = 0.02135, precision = 0.00784, map = 0.01311
# Epoch 521 (train)25.8s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216
# Epoch 522 (train)25.8s: train loss = 0.00293 = (mf)0.00077 + (embed)0.00216
# Epoch 523 (train)26.0s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216
# Epoch 524 (train)25.8s: train loss = 0.00291 = (mf)0.00075 + (embed)0.00216
# Epoch 525 (train)25.8s: train loss = 0.00290 = (mf)0.00074 + (embed)0.00216
# Epoch 526 (train)26.0s: train loss = 0.00289 = (mf)0.00073 + (embed)0.00216
# Epoch 527 (train)25.9s: train loss = 0.00288 = (mf)0.00072 + (embed)0.00216
# Epoch 528 (train)26.0s: train loss = 0.00293 = (mf)0.00077 + (embed)0.00216
# Epoch 529 (train)26.2s: train loss = 0.00291 = (mf)0.00075 + (embed)0.00216
# Epoch 530 (train)26.1s + (eval)10.2s: train loss = 0.00288 = (mf)0.00072 + (embed)0.00216, recall = 0.03049, ndcg = 0.02135, precision = 0.00783, map = 0.01308
# Epoch 531 (train)25.8s: train loss = 0.00293 = (mf)0.00077 + (embed)0.00216
# Epoch 532 (train)25.7s: train loss = 0.00289 = (mf)0.00073 + (embed)0.00216
# Epoch 533 (train)25.7s: train loss = 0.00291 = (mf)0.00075 + (embed)0.00216
# Epoch 534 (train)25.8s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216
# Epoch 535 (train)25.9s: train loss = 0.00291 = (mf)0.00076 + (embed)0.00216
# Epoch 536 (train)25.8s: train loss = 0.00291 = (mf)0.00075 + (embed)0.00216
# Epoch 537 (train)25.7s: train loss = 0.00287 = (mf)0.00071 + (embed)0.00216
# Epoch 538 (train)25.7s: train loss = 0.00291 = (mf)0.00076 + (embed)0.00216
# Epoch 539 (train)25.7s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216
# Epoch 540 (train)25.9s + (eval)10.1s: train loss = 0.00291 = (mf)0.00075 + (embed)0.00216, recall = 0.03043, ndcg = 0.02134, precision = 0.00780, map = 0.01311
# Epoch 541 (train)25.9s: train loss = 0.00285 = (mf)0.00069 + (embed)0.00216
# Epoch 542 (train)26.0s: train loss = 0.00287 = (mf)0.00071 + (embed)0.00216
# Epoch 543 (train)26.0s: train loss = 0.00288 = (mf)0.00072 + (embed)0.00216
# Epoch 544 (train)25.9s: train loss = 0.00290 = (mf)0.00074 + (embed)0.00216
# Epoch 545 (train)26.2s: train loss = 0.00290 = (mf)0.00074 + (embed)0.00216
# Epoch 546 (train)26.0s: train loss = 0.00290 = (mf)0.00074 + (embed)0.00216
# Epoch 547 (train)25.7s: train loss = 0.00291 = (mf)0.00075 + (embed)0.00216
# Epoch 548 (train)25.7s: train loss = 0.00287 = (mf)0.00071 + (embed)0.00216
# Epoch 549 (train)25.8s: train loss = 0.00289 = (mf)0.00073 + (embed)0.00216
# Epoch 550 (train)25.8s + (eval)10.1s: train loss = 0.00289 = (mf)0.00074 + (embed)0.00216, recall = 0.03079, ndcg = 0.02152, precision = 0.00791, map = 0.01319
# Epoch 551 (train)26.0s: train loss = 0.00287 = (mf)0.00071 + (embed)0.00216
# Epoch 552 (train)25.9s: train loss = 0.00288 = (mf)0.00072 + (embed)0.00216
# Epoch 553 (train)26.0s: train loss = 0.00289 = (mf)0.00073 + (embed)0.00216
# Epoch 554 (train)25.7s: train loss = 0.00289 = (mf)0.00073 + (embed)0.00216
# Epoch 555 (train)26.2s: train loss = 0.00288 = (mf)0.00072 + (embed)0.00216
# Epoch 556 (train)26.0s: train loss = 0.00288 = (mf)0.00072 + (embed)0.00216
# Epoch 557 (train)25.9s: train loss = 0.00286 = (mf)0.00070 + (embed)0.00216
# Epoch 558 (train)25.8s: train loss = 0.00286 = (mf)0.00070 + (embed)0.00216
# Epoch 559 (train)25.7s: train loss = 0.00292 = (mf)0.00076 + (embed)0.00216
# Epoch 560 (train)25.6s + (eval)10.2s: train loss = 0.00285 = (mf)0.00070 + (embed)0.00216, recall = 0.03065, ndcg = 0.02149, precision = 0.00787, map = 0.01320
# Epoch 561 (train)25.6s: train loss = 0.00285 = (mf)0.00069 + (embed)0.00216
# Epoch 562 (train)25.7s: train loss = 0.00286 = (mf)0.00070 + (embed)0.00216
# Epoch 563 (train)25.9s: train loss = 0.00286 = (mf)0.00071 + (embed)0.00215
# Epoch 564 (train)25.8s: train loss = 0.00290 = (mf)0.00074 + (embed)0.00216
# ...
# Epoch 815 (train)25.8s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 816 (train)25.6s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 817 (train)25.8s: train loss = 0.00275 = (mf)0.00062 + (embed)0.00213
# Epoch 818 (train)25.7s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 819 (train)25.6s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 820 (train)25.7s + (eval)10.1s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213, recall = 0.03056, ndcg = 0.02133, precision = 0.00782, map = 0.01307
# Epoch 821 (train)25.7s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 822 (train)25.8s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 823 (train)25.7s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 824 (train)25.7s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 825 (train)25.8s: train loss = 0.00273 = (mf)0.00059 + (embed)0.00213
# Epoch 826 (train)25.7s: train loss = 0.00276 = (mf)0.00062 + (embed)0.00213
# Epoch 827 (train)25.8s: train loss = 0.00275 = (mf)0.00061 + (embed)0.00213
# Epoch 828 (train)25.9s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 829 (train)25.8s: train loss = 0.00275 = (mf)0.00062 + (embed)0.00213
# Epoch 830 (train)25.7s + (eval)10.2s: train loss = 0.00274 = (mf)0.00060 + (embed)0.00213, recall = 0.03042, ndcg = 0.02140, precision = 0.00780, map = 0.01320
# Epoch 831 (train)25.7s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00213
# Epoch 832 (train)25.6s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 833 (train)25.7s: train loss = 0.00275 = (mf)0.00062 + (embed)0.00213
# Epoch 834 (train)25.8s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 835 (train)26.1s: train loss = 0.00274 = (mf)0.00060 + (embed)0.00213
# Epoch 836 (train)26.1s: train loss = 0.00275 = (mf)0.00062 + (embed)0.00213
# Epoch 837 (train)26.2s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 838 (train)26.0s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 839 (train)26.2s: train loss = 0.00274 = (mf)0.00060 + (embed)0.00213
# Epoch 840 (train)26.3s + (eval)10.2s: train loss = 0.00273 = (mf)0.00059 + (embed)0.00213, recall = 0.03077, ndcg = 0.02149, precision = 0.00786, map = 0.01321
# Epoch 841 (train)25.8s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 842 (train)25.8s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 843 (train)26.1s: train loss = 0.00273 = (mf)0.00059 + (embed)0.00213
# Epoch 844 (train)25.8s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 845 (train)26.2s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 846 (train)25.8s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 847 (train)25.7s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 848 (train)25.6s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 849 (train)25.6s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 850 (train)25.7s + (eval)10.1s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213, recall = 0.03097, ndcg = 0.02157, precision = 0.00791, map = 0.01322
# Epoch 851 (train)25.8s: train loss = 0.00273 = (mf)0.00059 + (embed)0.00213
# Epoch 852 (train)25.8s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 853 (train)25.6s: train loss = 0.00271 = (mf)0.00057 + (embed)0.00213
# Epoch 854 (train)25.8s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 855 (train)25.6s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 856 (train)25.8s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00213
# Epoch 857 (train)25.5s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 858 (train)25.5s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 859 (train)25.6s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 860 (train)25.7s + (eval)10.4s: train loss = 0.00273 = (mf)0.00059 + (embed)0.00213, recall = 0.03094, ndcg = 0.02152, precision = 0.00790, map = 0.01316
# Epoch 861 (train)25.6s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 862 (train)25.8s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 863 (train)25.7s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 864 (train)25.8s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 865 (train)26.2s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 866 (train)26.3s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 867 (train)25.8s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 868 (train)25.8s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 869 (train)25.9s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 870 (train)25.7s + (eval)10.1s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213, recall = 0.03083, ndcg = 0.02139, precision = 0.00786, map = 0.01307
# Epoch 871 (train)25.4s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 872 (train)25.5s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 873 (train)25.5s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 874 (train)25.7s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 875 (train)25.7s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 876 (train)25.9s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 877 (train)25.8s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 878 (train)25.8s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 879 (train)25.7s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 880 (train)25.8s + (eval)10.4s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213, recall = 0.03089, ndcg = 0.02146, precision = 0.00790, map = 0.01312
# Epoch 881 (train)25.9s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 882 (train)25.7s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 883 (train)25.7s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 884 (train)25.7s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 885 (train)25.6s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 886 (train)25.8s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 887 (train)26.0s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 888 (train)25.9s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 889 (train)26.0s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 890 (train)25.7s + (eval)10.2s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213, recall = 0.03100, ndcg = 0.02149, precision = 0.00790, map = 0.01314
# Epoch 891 (train)25.7s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 892 (train)25.6s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 893 (train)25.6s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 894 (train)25.8s: train loss = 0.00272 = (mf)0.00060 + (embed)0.00213
# Epoch 895 (train)25.5s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 896 (train)25.7s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00213
# Epoch 897 (train)26.0s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 898 (train)25.9s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 899 (train)25.9s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Save model to path /home/wakatsuki/kaggle/h-and-m-personalized-fashion-recommendations/output/epoch_900
# Epoch 900 (train)25.9s + (eval)10.4s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213, recall = 0.03097, ndcg = 0.02160, precision = 0.00789, map = 0.01328
# Epoch 901 (train)25.8s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 902 (train)25.7s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 903 (train)25.5s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 904 (train)25.6s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00213
# Epoch 905 (train)25.6s: train loss = 0.00269 = (mf)0.00056 + (embed)0.00213
# Epoch 906 (train)25.8s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 907 (train)25.8s: train loss = 0.00273 = (mf)0.00061 + (embed)0.00213
# Epoch 908 (train)25.7s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 909 (train)25.8s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 910 (train)25.8s + (eval)10.2s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213, recall = 0.03075, ndcg = 0.02150, precision = 0.00785, map = 0.01322
# Epoch 911 (train)25.6s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00213
# Epoch 912 (train)25.7s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 913 (train)26.0s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00213
# Epoch 914 (train)25.8s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00213
# Epoch 915 (train)25.9s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 916 (train)26.0s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 917 (train)26.0s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 918 (train)25.9s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00213
# Epoch 919 (train)25.9s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 920 (train)25.8s + (eval)10.4s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213, recall = 0.03054, ndcg = 0.02126, precision = 0.00781, map = 0.01300
# Epoch 921 (train)25.7s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00213
# Epoch 922 (train)25.7s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00213
# Epoch 923 (train)25.7s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213
# Epoch 924 (train)25.7s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 925 (train)26.0s: train loss = 0.00272 = (mf)0.00060 + (embed)0.00213
# Epoch 926 (train)26.1s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 927 (train)25.8s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00213
# Epoch 928 (train)25.7s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 929 (train)25.7s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00213
# Epoch 930 (train)25.7s + (eval)10.1s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00213, recall = 0.03064, ndcg = 0.02130, precision = 0.00781, map = 0.01303
# Epoch 931 (train)26.0s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 932 (train)25.6s: train loss = 0.00274 = (mf)0.00061 + (embed)0.00213
# Epoch 933 (train)25.6s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 934 (train)25.9s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00213
# Epoch 935 (train)26.1s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00213
# Epoch 936 (train)25.7s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 937 (train)26.0s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00213
# Epoch 938 (train)26.0s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00213
# Epoch 939 (train)26.0s: train loss = 0.00272 = (mf)0.00060 + (embed)0.00213
# Epoch 940 (train)26.3s + (eval)10.3s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213, recall = 0.03052, ndcg = 0.02121, precision = 0.00776, map = 0.01296
# Epoch 941 (train)25.6s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00213
# Epoch 942 (train)25.7s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 943 (train)25.7s: train loss = 0.00269 = (mf)0.00057 + (embed)0.00213
# Epoch 944 (train)25.6s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 945 (train)25.6s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212
# Epoch 946 (train)25.7s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212
# Epoch 947 (train)26.0s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00213
# Epoch 948 (train)26.0s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212
# Epoch 949 (train)25.9s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00213
# Epoch 950 (train)25.8s + (eval)10.1s: train loss = 0.00267 = (mf)0.00055 + (embed)0.00213, recall = 0.03069, ndcg = 0.02130, precision = 0.00781, map = 0.01302
# Epoch 951 (train)25.7s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00212
# Epoch 952 (train)25.6s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00212
# Epoch 953 (train)25.6s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00212
# Epoch 954 (train)25.6s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212
# Epoch 955 (train)25.5s: train loss = 0.00269 = (mf)0.00056 + (embed)0.00213
# Epoch 956 (train)25.7s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00213
# Epoch 957 (train)26.0s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00213
# Epoch 958 (train)26.0s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 959 (train)25.9s: train loss = 0.00269 = (mf)0.00057 + (embed)0.00213
# Epoch 960 (train)26.0s + (eval)10.2s: train loss = 0.00272 = (mf)0.00059 + (embed)0.00212, recall = 0.03068, ndcg = 0.02131, precision = 0.00784, map = 0.01300
# Epoch 961 (train)25.5s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00213
# Epoch 962 (train)25.6s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00212
# Epoch 963 (train)25.6s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00213
# Epoch 964 (train)25.8s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00212
# Epoch 965 (train)25.7s: train loss = 0.00273 = (mf)0.00061 + (embed)0.00212
# Epoch 966 (train)25.8s: train loss = 0.00269 = (mf)0.00057 + (embed)0.00212
# Epoch 967 (train)25.8s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00212
# Epoch 968 (train)25.7s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00212
# Epoch 969 (train)25.8s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00212
# Epoch 970 (train)25.8s + (eval)10.5s: train loss = 0.00273 = (mf)0.00060 + (embed)0.00213, recall = 0.03087, ndcg = 0.02135, precision = 0.00788, map = 0.01302
# Epoch 971 (train)25.8s: train loss = 0.00269 = (mf)0.00057 + (embed)0.00212
# Epoch 972 (train)25.8s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00212
# Epoch 973 (train)25.7s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212
# Epoch 974 (train)25.8s: train loss = 0.00269 = (mf)0.00056 + (embed)0.00212
# Epoch 975 (train)25.6s: train loss = 0.00269 = (mf)0.00057 + (embed)0.00212
# Epoch 976 (train)25.9s: train loss = 0.00269 = (mf)0.00056 + (embed)0.00213
# Epoch 977 (train)25.7s: train loss = 0.00269 = (mf)0.00056 + (embed)0.00212
# Epoch 978 (train)26.0s: train loss = 0.00269 = (mf)0.00057 + (embed)0.00212
# Epoch 979 (train)25.9s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00212
# Epoch 980 (train)25.7s + (eval)10.1s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212, recall = 0.03084, ndcg = 0.02142, precision = 0.00786, map = 0.01310
# Epoch 981 (train)25.8s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00212
# Epoch 982 (train)25.5s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00212
# Epoch 983 (train)25.8s: train loss = 0.00271 = (mf)0.00059 + (embed)0.00212
# Epoch 984 (train)25.9s: train loss = 0.00268 = (mf)0.00056 + (embed)0.00212
# Epoch 985 (train)25.7s: train loss = 0.00268 = (mf)0.00056 + (embed)0.00212
# Epoch 986 (train)25.7s: train loss = 0.00269 = (mf)0.00057 + (embed)0.00212
# Epoch 987 (train)25.9s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212
# Epoch 988 (train)25.9s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212
# Epoch 989 (train)25.7s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00212
# Epoch 990 (train)25.7s + (eval)10.1s: train loss = 0.00271 = (mf)0.00058 + (embed)0.00212, recall = 0.03076, ndcg = 0.02139, precision = 0.00782, map = 0.01312
# Epoch 991 (train)26.0s: train loss = 0.00272 = (mf)0.00060 + (embed)0.00212
# Epoch 992 (train)26.0s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212
# Epoch 993 (train)26.0s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00212
# Epoch 994 (train)26.0s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00212
# Epoch 995 (train)25.6s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212
# Epoch 996 (train)26.0s: train loss = 0.00270 = (mf)0.00057 + (embed)0.00212
# Epoch 997 (train)26.5s: train loss = 0.00269 = (mf)0.00056 + (embed)0.00212
# Epoch 998 (train)26.1s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212
# Epoch 999 (train)26.5s: train loss = 0.00268 = (mf)0.00056 + (embed)0.00212
# Save model to path /home/wakatsuki/kaggle/h-and-m-personalized-fashion-recommendations/output/epoch_1000
# Epoch 1000 (train)26.5s + (eval)10.3s: train loss = 0.00270 = (mf)0.00058 + (embed)0.00212, recall = 0.03058, ndcg = 0.02136, precision = 0.00783, map = 0.01309
# 27026.991304333 sec

# %%
# to avoid oom
tmp = valid[['userID']].drop_duplicates()
step = len(tmp) // 10
res = []
for i in range(0, len(tmp), step):
    res.append(model.recommend_k_items(tmp.iloc[i:i+step], top_k=12, remove_seen=False))
pred = pd.concat(res).reset_index(drop=True)
del tmp

# %%
pred = pred.rename(columns={'userID': 'user', 'itemID': 'item_pred'})
pred = pred.groupby('user')['item_pred'].apply(list).reset_index()
pred
# Out:
#           user                                          item_pred
# 0           86  [27905, 102710, 105077, 33868, 100228, 102472,...
# 1          107  [61303, 61305, 2219, 61296, 13042, 92029, 6130...
# 2          179  [104986, 3510, 105180, 95216, 95217, 3520, 105...
# 3          330  [103796, 102240, 99399, 71106, 88269, 104840, ...
# 4          349  [2252, 87495, 99222, 101695, 103862, 2260, 942...
# ...        ...                                                ...
# 35249  1371691  [3091, 104192, 104193, 2480, 56694, 104157, 82...
# 35250  1371717  [100308, 95442, 100184, 97192, 95202, 95208, 9...
# 35251  1371747  [82628, 82631, 99023, 56694, 99766, 75438, 102...
# 35252  1371813  [28989, 38565, 38564, 86991, 99944, 73, 104413...
# 35253  1371960  [94700, 94699, 54338, 54341, 103304, 88821, 94...
#
# [35254 rows x 2 columns]

# %%
valid = pd.read_pickle(INPUT_DIR / 'transactions_train.pkl')[['user', 'item', 't_dat']].query("t_dat >= @valid_start_date")[['user', 'item']].rename(columns={'item': 'item_valid'}).reset_index(drop=True)
valid = valid.groupby('user')['item_valid'].apply(list).reset_index()
valid
# Out:
#           user                                         item_valid
# 0           80                                            [28967]
# 1           86                                            [87371]
# 2          107                              [69711, 77256, 33872]
# 3          117                                            [97391]
# 4          179  [102397, 98409, 73, 95784, 103796, 105103, 103...
# ...        ...                                                ...
# 68979  1371868                                    [97531, 103424]
# 68980  1371871                                     [94310, 91533]
# 68981  1371879  [2118, 84994, 57078, 84991, 101099, 104036, 87...
# 68982  1371937                                     [67261, 70640]
# 68983  1371960                                           [101689]
#
# [68984 rows x 2 columns]

# %%
merged = valid.merge(pred, on='user')
mpk = mapk(merged['item_valid'], merged['item_pred'])
users_valid = set(valid['user'])
users_merged = set(merged['user'])
user_coverage = len(users_valid & users_merged) / len(users_valid)
print(f"mapk: {mpk}, user coverage: {user_coverage}")
# Out:
# mapk: 0.030309306049699523, user coverage: 0.5110460396613707

# %%
pred.to_csv(OUTPUT_DIR / 'pred.csv', index=False)
model.infer_embedding(OUTPUT_DIR / 'user_emb.csv', OUTPUT_DIR / 'item_emb.csv')

# %% [markdown]
# users which are not included in pred

# %%
item_emb = pd.read_csv(OUTPUT_DIR / 'item_emb.csv', sep='\t', names=['item', 'emb'])
item_emb['emb'] = item_emb['emb'].apply(lambda x: list(map(float, x.split(' '))))

# %%
users_in_pred = pred['user'].values
items_with_emb = item_emb['item'].values

# %%
transactions = pd.read_pickle(INPUT_DIR / 'transactions_train.pkl')[['user', 'item', 't_dat']]
transactions = transactions.query("user not in @users_in_pred")
transactions = transactions.query("item in @items_with_emb")

pred2 = transactions.query("@train_start_date <= t_dat < @valid_start_date").reset_index(drop=True)

pred2['sz'] = pred2.groupby(['user', 'item'])['item'].transform('size')
pred2 = pred2.sort_values(by=['user', 't_dat', 'sz'], ascending=False)

pred2 = pred2[['user', 'item']].drop_duplicates(ignore_index=True)

pred2 = pred2.groupby('user')['item'].apply(list).reset_index()
pred2['item'] = pred2['item'].apply(lambda x: x[0])
pred2
# Out:
#            user    item
# 0             0   16023
# 1             2   78503
# 2             4  101367
# 3             6   58295
# 4            10   70320
# ...         ...     ...
# 359157  1371963   96812
# 359158  1371969   82965
# 359159  1371975   56446
# 359160  1371976   71110
# 359161  1371977   71107
#
# [359162 rows x 2 columns]

# %%
pred2 = pred2.merge(item_emb, on='item')
pred2
# Out:
#            user   item                                                emb
# 0             0  16023  [-0.28671965, 0.12319042, -0.63971883, 0.42827...
# 1          3768  16023  [-0.28671965, 0.12319042, -0.63971883, 0.42827...
# 2          5087  16023  [-0.28671965, 0.12319042, -0.63971883, 0.42827...
# 3         13619  16023  [-0.28671965, 0.12319042, -0.63971883, 0.42827...
# 4         23672  16023  [-0.28671965, 0.12319042, -0.63971883, 0.42827...
# ...         ...    ...                                                ...
# 359157  1369454  24620  [0.15362547, -0.039421372, -0.17271936, 0.1061...
# 359158  1370000  79596  [-0.0012258235, -0.0028024204, 0.0025917648, -...
# 359159  1370569  89908  [-0.22764343, 0.082736336, -0.13961723, 0.1079...
# 359160  1370608  77220  [-0.0010128412, -0.0016582329, 0.0010389092, -...
# 359161  1371274  93859  [-0.36956415, -0.052816957, 0.12073449, 0.2427...
#
# [359162 rows x 3 columns]

# %%
emb = np.array(item_emb['emb'].values.tolist(), dtype=np.float32)
pred2_emb = np.array(pred2['emb'].values.tolist(), dtype=np.float32)

# %%
index = faiss.index_factory(128, "Flat", faiss.METRIC_INNER_PRODUCT)
index = faiss.index_cpu_to_gpu(faiss.StandardGpuResources(), 0, index)
index.add(emb)
_, nns = index.search(pred2_emb, 12)

# %%
mp = item_emb['item'].values
pred2['item_pred'] = [mp[nn].tolist() for nn in nns]

# %%
assert len(set(pred.user) & set(pred2.user)) == 0
pred_merged = pd.concat([pred, pred2[['user', 'item_pred']]]).reset_index(drop=True)

# %%
merged = valid.merge(pred_merged, on='user')
mpk = mapk(merged['item_valid'], merged['item_pred'])
users_valid = set(valid['user'])
users_merged = set(merged['user'])
user_coverage = len(users_valid & users_merged) / len(users_valid)
print(f"mapk: {mpk}, user coverage: {user_coverage}")
# Out:
# mapk: 0.03219380101620936, user coverage: 0.6265800765394874

# %% [markdown]
# users without transactions

# %%
start_date = valid_start_date - datetime.timedelta(days=7)
end_date = valid_start_date - datetime.timedelta(days=1)
transactions = pd.read_pickle(INPUT_DIR / 'transactions_train.pkl')[['t_dat', 'user', 'item']].query("@start_date <= t_dat <= @end_date")
users = pd.read_pickle(INPUT_DIR / 'users.pkl')[['user', 'age']]

transactions_age = transactions.query("@start_date <= t_dat <= @end_date").merge(users, on='user')
transactions_age['age'] = transactions_age['age'].fillna(0).astype(int)
age_volume = transactions_age.groupby('age').size().reset_index(name='sz').sort_values(by='age')
sz_threshold = age_volume.query("24 <= age <= 26").sz.sum()  # 最もtransactionsのボリュームが大きい25歳で幅1を取ったときの数を基準とする

# 各ageに対して閾値を超える最小の幅を求める
age_width = {}
for age in range(10, 100):
    for d in range(1, 100):
        lb = age - d
        ub = age + d
        sz = age_volume.query("@lb <= age <= @ub").sz.sum()
        if sz >= sz_threshold:
            age_width[age] = d
            break

age_items = {}
for age in range(10, 100):
    lb = age - age_width[age]
    ub = age + age_width[age]
    age_items[age] = transactions_age.query("@lb <= age <= @ub").groupby('item').size().reset_index(
        name='sz').sort_values(by='sz', ascending=False)['item'].values[:12].tolist()

# age: nanには全体の人気商品を割り当てる
age_items[0] = transactions_age.groupby('item').size().reset_index(
    name='sz').sort_values(by='sz', ascending=False)['item'].values[:12].tolist()

age_pred = pd.DataFrame([{'age': k, 'item': v} for k, v in age_items.items()])

# %%
pred3 = valid[['user']].merge(users, on='user')
pred3['age'] = pred3['age'].fillna(0).astype(int)
pred3 = pred3.merge(age_pred, on='age')[['user', 'item']].rename(columns={'item': 'item_pred'}).reset_index(drop=True)

# %%
users = set(pred.user.values) | set(pred2.user.values)
pred3 = pred3.query("user not in @users")
pred_merged = pd.concat([pred, pred2, pred3]).reset_index(drop=True)

# %%
merged = valid.merge(pred_merged, on='user')
mpk = mapk(merged['item_valid'], merged['item_pred'])
users_valid = set(valid['user'])
users_merged = set(merged['user'])
user_coverage = len(users_valid & users_merged) / len(users_valid)
print(f"mapk: {mpk}, user coverage: {user_coverage}")
# Out:
# mapk: 0.023526232420249402, user coverage: 1.0
